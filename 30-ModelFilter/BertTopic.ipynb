# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
! pip install bertopic
# Out:
# ...
#      |████████████████████████████████| 57 kB 2.6 MB/s
# ...
#      |████████████████████████████████| 5.2 MB 8.1 MB/s
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#     Preparing wheel metadata ... done
# ...
#      |████████████████████████████████| 88 kB 8.1 MB/s
# ...
#      |████████████████████████████████| 79 kB 10.5 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 54.7 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 60.6 MB/s
# ...
#      |████████████████████████████████| 77 kB 7.7 MB/s
# ...
#      |████████████████████████████████| 636 kB 88.3 MB/s
# ...
#      |████████████████████████████████| 6.6 MB 62.4 MB/s
# ...
#      |████████████████████████████████| 895 kB 67.3 MB/s
# ...
#      |████████████████████████████████| 1.1 MB 64.4 MB/s
# ...
#   Created wheel for hdbscan: filename=hdbscan-0.8.28-cp37-cp37m-linux_x86_64.whl size=2330812 sha256=715db2e6ec4c310f91f41e40052c104a75724e0419c2885527b7fcf6633fb76d
# ...

# %%
from bertopic import BERTopic
from sklearn.datasets import fetch_20newsgroups

docs = fetch_20newsgroups(subset='all',  remove=('headers', 'footers', 'quotes'))['data']

topic_model = BERTopic()
topics, probs = topic_model.fit_transform(docs)
# Out:
# Downloading:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/10.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/349 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading:   0%|          | 0.00/232k [00:00<?, ?B/s]
# ...

# %%
topic_model.get_topic_info()
# Out:
#      Topic  Count                                       Name
# 0       -1   6554                            -1_to_the_is_of
# 1        0   1840                       0_game_team_games_he
# 2        1    572              1_key_clipper_chip_encryption
# 3        2    526                       2_ites_cheek_yep_huh
# 4        3    458                 3_israel_israeli_jews_arab
# ..     ...    ...                                        ...
# 198    205     11               205_42_tea_question_universe
# 207    206     10  206_carcinogens_meat_barbecuing_barbecued
# 208    207     10                   207_quack_lyme_quacks_ld
# 209    208     10       208_altitude_everest_oxygen_pressure
# 210    209     10               209_dvx_network_link_windows
#
# [211 rows x 3 columns]

# %%
topic_model.get_topic(0)
# Out:
# [('game', 0.010495461057833139),
#  ('team', 0.009124308458192862),
#  ('games', 0.007264762135395508),
#  ('he', 0.007214325843282413),
#  ('players', 0.006386583896904834),
#  ('season', 0.006304371540070922),
#  ('hockey', 0.006165970132757784),
#  ('play', 0.005840059289696956),
#  ('25', 0.005713491866874745),
#  ('year', 0.005700486212897672)]

# %%
topic_model.visualize_topics()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
% cd drive/MyDrive/transformer/nissan/
# Out:
# /content/drive/MyDrive/transformer/nissan

# %%
import pandas as pd

# %%
comments = pd.read_csv('all_comments.csv', encoding_errors='ignore')
comments
# Out:
#       Model    Souce                                            Comment
# 0     Rogue     Cars  I’ve had my 2021 Rogue SL with the premium pac...
# 1     Rogue     Cars  I have to preface this by saying I purchased a...
# 2     Rogue     Cars  Recently traded in my 2016 for the new redesig...
# 3     Rogue     Cars  Meets our needs comfortable  stylish love the ...
# 4     Rogue     Cars  Always have been a huge fan of Rogues but I ab...
# ...     ...      ...                                                ...
# 4634   RAV4  Edmunds  Bought HNov. 21 to drive back and forth from A...
# 4635   RAV4  Edmunds  I have a 2021 Rav 4 Hybrid with 6000 kilometer...
# 4636   RAV4  Edmunds  The tailgate rattles like no SUV I’ve ever own...
# 4637   RAV4  Edmunds  I purchased my 2021 Toyota Rav4 new in August....
# 4638   RAV4  Edmunds  First, the fuel economy is great. Although it ...
#
# [4639 rows x 3 columns]

# %%
comments.groupby('Model').count()
# Out:
#               Souce  Comment
# Model
# Bronco Sport    197      197
# CR-V            915      915
# CX-5            527      527
# Equinox         377      377
# Escape          332      328
# Forester        353      353
# RAV4            819      819
# Rogue           321      321
# Sportage        394      394
# Tucson          404      404

# %%
comments_rogue = [str(i).lower() for i in comments[comments['Model'] == 'CR-V']['Comment'].tolist()]
len(comments_rogue)
# Out:
# 915

# %%
topic_model = BERTopic(min_topic_size = 10)
topics, probs = topic_model.fit_transform(comments_rogue)

# %%
topic_model.get_topic_info()
# Out:
#     Topic  Count                                Name
# 0       0     64                0_love_and_great_all
# 1       1     51                           1_none___
# 2       2     35                  2_honda_crv_the_is
# 3       3     27                3_me_safe_startup_cd
# 4       4     25          4_best_choice_cargo_2ndrow
# 5      -1     24                   -1_crv_my_cx_2021
# 6       5     22      5_class_which_concern_advanced
# 7       6     21             6_fun_mileage_drive_gas
# 8       7     21               7_2018_hope_2022_sine
# 10     10     20            10_self_mess_contours_it
# 11      8     20           8_road_great_car_mountain
# 9       9     20               9_at_problem_was_feet
# 12     11     19       11_comfort_safety_mileage_gas
# 13     12     19                  12_also_lx_very_of
# 14     13     19               13_mi_crvs_really_gas
# 15     14     19  14_seating_smooth_ride_comfortable
# 16     15     19             15_honda_and_all_hondas
# ...

# %%
topic_model.get_topic(10)
# Out:
# [('self', 0.1117384717344516),
#  ('mess', 0.06743679080753798),
#  ('contours', 0.06743679080753798),
#  ('it', 0.06647771808323508),
#  ('lights', 0.06470565130822581),
#  ('amazing', 0.06388765774138487),
#  ('long', 0.06165400957789053),
#  ('so', 0.05672983725912843),
#  ('helps', 0.0558692358672258),
#  ('them', 0.05319518933368632)]
